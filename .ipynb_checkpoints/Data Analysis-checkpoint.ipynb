# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from load_json import *
from PDF import *

# %%
path_disr = 'Data\DB_TCV_DISR.json'
data_disr = load_json(path_disr)

# %%
path_shot = 'Data\TCV_DATAno63847.parquet'
data_shot = pd.read_parquet(path_regular, engine='fastparquet')

# %%
data_regular.keys()
# Out:
# Index(['time', 'FIR_core', 'PD', 'DML', 'IP'], dtype='object')

# %%
t = data_regular['time']
FIR_core = data_regular['FIR_core']
PD = data_regular['PD']
DML = data_regular['DML']
IP = data_regular['IP']
# Out:
# ((array([0.00040416, 0.00011547, 0.00011547, 0.00075058, 0.00542725,
#          0.00606236, 0.0358545 , 0.08360277, 0.04942263, 0.03625866,
#          0.03562356, 0.11426097, 0.022806  , 0.0039261 , 0.0034642 ,
#          0.01068129, 0.02933025, 0.03146651, 0.03296767, 0.02898383,
#          0.03389145, 0.03995381, 0.05490762, 0.08937644, 0.09399538,
#          0.047806  , 0.03822171, 0.02742494, 0.02009238, 0.01247113,
#          0.00733256, 0.00300231]),
#   array([ 2.7763734 ,  2.6723037 ,  2.568234  ,  2.4641638 ,  2.360094  ,
#           2.2560241 ,  2.1519544 ,  2.0478842 ,  1.9438144 ,  1.8397444 ,
#           1.7356744 ,  1.6316047 ,  1.5275346 ,  1.4234649 ,  1.3193948 ,
#           1.215325  ,  1.111255  ,  1.0071852 ,  0.9031153 ,  0.7990454 ,
#           0.6949755 ,  0.5909055 ,  0.4868356 ,  0.3827657 ,  0.27869582,
#           0.1746259 ,  0.07055598, -0.03351393, -0.13758384, -0.24165374,
#          -0.34572366, -0.44979358], dtype=float32)),
#  -0.00037185877)

# %%
def clean_data(pd_series):
    series_array = np.array(pd_series)
    return series_array[~np.isnan(series_array)]

# %%
type(FIR_core)

# %%
clean_data(FIR_core)

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(t, FIR_core)
axs[0, 0].set_title('FIR_core')
axs[0, 1].plot(t, PD, 'tab:orange')
axs[0, 1].set_title('PD')
axs[1, 0].plot(t, DML, 'tab:green')
axs[1, 0].set_title('DML')
axs[1, 1].plot(t, IP, 'tab:red')
axs[1, 1].set_title('IP')
fig.tight_layout()

# %%
IP_segments = data['no63847']['Discharge']['IP_segments']
print_dict_structure(IP_segments, 2)
Ramp_up = IP_segments['Ramp_up']
Flat_top = IP_segments['Flat_top']
Ramp_down = IP_segments['Ramp_down']
plt.plot(Ramp_up)
plt.plot(Flat_top)
plt.plot(Ramp_down)

# %%
Ramp_up

# %%
Flat_top

# %%
Ramp_down

# %%
def PDF(shot):
    return 0

# %%
PDF([1, 2, 3])

# %%
plt.plot(x, pdf)

# %%
x, pdf
